# %% [markdown]
# # Sentiment Analysis on tweets about Ohio elections
# <br>
#
#
# #### Scope
# 1- Pull tweets by the hashtags below </b> <br>
# 2- Perform sentiment analysis </b> <br>
# 3- Visualize results </b> <br>
#
# <br>
#
# ##### Hashtags
# ***
# 2022 Senate elections in Ohio:
# <br>
#
#     J.D. Vance (Republican) >> #JDVance
#     Tim Ryan (Democratic)  >> #TimRyan
# ***
#
# <br>
#
# *Sample size*:  4500 tweets for each candidate (total of 9000 tweets)
# <br>
# *Sample date range*: Jan 2022 to Nov 3rd 2022
#
# <br>
#
# **Models used**:
#
# - snscrape to pull tweets
# Github Repo: https://github.com/JustAnotherArchivist/snscrape
# <br>
#
# - Twitter-roBERTa-base for Sentiment Analysis - UPDATED (2021)
# This is a roBERTa-base model trained on ~124M tweets from January 2018 to December 2021, and finetuned for sentiment analysis with the TweetEval benchmark
# https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment-latest?text=Covid+cases+are+increasing+fast%21

# %%
# # importing libraries and packages
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from transformers import pipeline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### 1. Pull Tweets on each candidate

# %%
def tweets_scraper(candidate):

    # Creating list to append tweet data
    tweets_list = []
    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i, tweet in tqdm(
        enumerate(
            sntwitter.TwitterSearchScraper(
                f"#{candidate} since:2022-01-01 until:2022-11-04"
            ).get_items()
        ),
        total=4_500,
    ):  # declare a username
        if i > 4_500:  # number of tweets you want to scrape
            break
        tweets_list.append(
            [tweet.date, tweet.id, tweet.content, tweet.user.username]
        )  # declare the attributes to be returned
    # Creating a dataframe from the tweets list above
    tweet_df = pd.DataFrame(
        tweets_list, columns=["Datetime", "Tweet Id", "Text", "Username"]
    )
    
    return tweet_df

# %%
# tweets #jdvance and #timryan 

jdvance_tweets = tweets_scraper("JDVance")
timryan_tweets = tweets_scraper("TimRyan")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4500.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=4500.0), HTML(value='')))

# %%
jdvance_tweets.head(5)
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-11-03 23:52:51+00:00  1588318319324860417
# 1 2022-11-03 23:45:53+00:00  1588316564163813376
# 2 2022-11-03 23:31:44+00:00  1588313006076821504
# 3 2022-11-03 22:19:40+00:00  1588294867750645760
# 4 2022-11-03 21:55:37+00:00  1588288816040665089
#
#                                                 Text       Username
# 0           @TimRyan Vote Red all the way ! #JDVance   HattiePittie
# 1  @InBed17 🤣I don't even want Trump in 2024 \n\n...      pamp00vey
# 2  #TrumpRally\n#OhioTrumpRally\n#Ohio\n#JDVance ...      pamp00vey
# 3  @TimRyan @MrScottLads Putting it simply, \n\n#...    universenus
# 4  @TimRyan YOU ARE GOING TO WIN TIM. YOU ARE AUT...  lovepeace3124

# %% [markdown]
# #### 2.Sentiment Analysis

# %%
# test model
model = f"cardiffnlp/twitter-roberta-base-sentiment-latest"

sentiment_task = pipeline("sentiment-analysis", model=model)
sentiment_task("Covid cases are increasing fast!")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'label': 'Negative', 'score': 0.7235768437385559}]

# %%
# flag each df with the #hashtag and then concat

jdvance_tweets['Hashtag'] = 'JDVance'
timryan_tweets['Hashtag'] = 'TimRyan'

tweet_df = pd.concat([jdvance_tweets, timryan_tweets])
tweet_df
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-11-03 23:52:51+00:00  1588318319324860417
# 1     2022-11-03 23:45:53+00:00  1588316564163813376
# 2     2022-11-03 23:31:44+00:00  1588313006076821504
# 3     2022-11-03 22:19:40+00:00  1588294867750645760
# 4     2022-11-03 21:55:37+00:00  1588288816040665089
# ...                         ...                  ...
# 4496  2022-04-12 13:35:47+00:00  1513873516998934535
# 4497  2022-04-11 16:08:08+00:00  1513549468095897602
# 4498  2022-04-11 14:17:16+00:00  1513521570374983683
# 4499  2022-04-10 19:28:19+00:00  1513237460427448326
# 4500  2022-04-10 18:46:59+00:00  1513227056045297670
#
#                                                    Text       Username  \
# 0              @TimRyan Vote Red all the way ! #JDVance   HattiePittie
# 1     @InBed17 🤣I don't even want Trump in 2024 \n\n...      pamp00vey
# 2     #TrumpRally\n#OhioTrumpRally\n#Ohio\n#JDVance ...      pamp00vey
# 3     @TimRyan @MrScottLads Putting it simply, \n\n#...    universenus
# 4     @TimRyan YOU ARE GOING TO WIN TIM. YOU ARE AUT...  lovepeace3124
# ...                                                 ...            ...
# 4496     YESSS! #TimRyan #OHSen https://t.co/8QSgpb1ajz       snoozeq1
# 4497  @NoLieWithBTC Glad he announced it! The GQP ca...  dinosaursindc
# 4498  Paging @TimRyan did you see this? \n\nRun it e...   DewOfHeaven2
# 4499  Dem leadership better be putting it all behind...     calatayud7
# 4500         #TimRyan\n@TimRyan https://t.co/xG8T1cztbF     KaysGramma
#
#       Hashtag
# 0     JDVance
# 1     JDVance
# 2     JDVance
# 3     JDVance
# 4     JDVance
# ...       ...
# 4496  TimRyan
# 4497  TimRyan
# 4498  TimRyan
# 4499  TimRyan
# 4500  TimRyan
#
# [9002 rows x 5 columns]

# %%
# run transformers model on all tweets

sent_results = {}
for i, d in tqdm(tweet_df.iterrows(), total=len(tweet_df)):
    sent = sentiment_task(d["Text"])
    sent_results[d["Tweet Id"]] = sent
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9002.0), HTML(value='')))

# %%
sent_df = pd.DataFrame(sent_results).T
sent_df["label"] = sent_df[0].apply(lambda x: x["label"])
sent_df["score"] = sent_df[0].apply(lambda x: x["score"])
sent_df = sent_df.merge(
    tweet_df.set_index("Tweet Id"), left_index=True, right_index=True
)

# %%
sent_df
# Out:
#                                                                      0  \
# 1513227056045297670  {'label': 'Neutral', 'score': 0.8795298337936401}
# 1513237460427448326  {'label': 'Negative', 'score': 0.5122110843658...
# 1513521570374983683  {'label': 'Neutral', 'score': 0.6774628758430481}
# 1513549468095897602  {'label': 'Positive', 'score': 0.9183974862098...
# 1513873516998934535  {'label': 'Positive', 'score': 0.9139376878738...
# ...                                                                ...
# 1588313006076821504  {'label': 'Neutral', 'score': 0.9133479595184326}
# 1588316077263814656  {'label': 'Negative', 'score': 0.9144390821456...
# 1588316146570100738  {'label': 'Neutral', 'score': 0.6852514147758484}
# 1588316564163813376  {'label': 'Negative', 'score': 0.4940989315509...
# 1588318319324860417  {'label': 'Neutral', 'score': 0.5495721101760864}
#
#                         label     score                   Datetime  \
# 1513227056045297670   Neutral  0.879530  2022-04-10 18:46:59+00:00
# 1513237460427448326  Negative  0.512211  2022-04-10 19:28:19+00:00
# 1513521570374983683   Neutral  0.677463  2022-04-11 14:17:16+00:00
# 1513549468095897602  Positive  0.918397  2022-04-11 16:08:08+00:00
# 1513873516998934535  Positive  0.913938  2022-04-12 13:35:47+00:00
# ...                       ...       ...                        ...
# 1588313006076821504   Neutral  0.913348  2022-11-03 23:31:44+00:00
# 1588316077263814656  Negative  0.914439  2022-11-03 23:43:56+00:00
# 1588316146570100738   Neutral  0.685251  2022-11-03 23:44:13+00:00
# 1588316564163813376  Negative  0.494099  2022-11-03 23:45:53+00:00
# 1588318319324860417   Neutral  0.549572  2022-11-03 23:52:51+00:00
#
#                                                                   Text  \
# 1513227056045297670         #TimRyan\n@TimRyan https://t.co/xG8T1cztbF
# 1513237460427448326  Dem leadership better be putting it all behind...
# 1513521570374983683  Paging @TimRyan did you see this? \n\nRun it e...
# 1513549468095897602  @NoLieWithBTC Glad he announced it! The GQP ca...
# 1513873516998934535     YESSS! #TimRyan #OHSen https://t.co/8QSgpb1ajz
# ...                                                                ...
# 1588313006076821504  #TrumpRally\n#OhioTrumpRally\n#Ohio\n#JDVance ...
# 1588316077263814656  @TimRyan You should show your buddy's boo-boo ...
# 1588316146570100738  @TimRyan Vote for @TimRyan \n#TimRyan for #Ohi...
# 1588316564163813376  @InBed17 🤣I don't even want Trump in 2024 \n\n...
# 1588318319324860417           @TimRyan Vote Red all the way ! #JDVance
#
#                           Username  Hashtag
# 1513227056045297670     KaysGramma  TimRyan
# 1513237460427448326     calatayud7  TimRyan
# 1513521570374983683   DewOfHeaven2  TimRyan
# 1513549468095897602  dinosaursindc  TimRyan
# 1513873516998934535       snoozeq1  TimRyan
# ...                            ...      ...
# 1588313006076821504      pamp00vey  JDVance
# 1588316077263814656       GBoy1982  TimRyan
# 1588316146570100738     MJResister  TimRyan
# 1588316564163813376      pamp00vey  JDVance
# 1588318319324860417   HattiePittie  JDVance
#
# [9002 rows x 7 columns]

# %%
sent_df.groupby("label")["score"].plot(kind="hist", bins=50)
plt.legend()
plt.show()

# %%
df = pd.read_csv("Data/tweets_labeled.csv")
summary = df.groupby(['Hashtag', 'label'])['score'].count().reset_index()
summary['pct'] = round(summary.score / 4501 * 100, 1)
summary = summary.rename(columns = {"label": 'Sentiment Label', 'score': 'Sentiment Count', 'pct': 'Pct of Tweets'})
summary
# Out:
#    Hashtag Sentiment Label  Sentiment Count  Pct of Tweets
# 0  JDVance        Negative             2240           49.8
# 1  JDVance         Neutral             1771           39.3
# 2  JDVance        Positive              490           10.9
# 3  TimRyan        Negative             1456           32.3
# 4  TimRyan         Neutral             1969           43.7
# 5  TimRyan        Positive             1076           23.9

# %% [markdown]
# #### 3.Visualize results

# %%
colors = ["#d3494e", "gray", '#7bb274']
sns.set_palette(sns.color_palette(colors))
# sns.set(style="white")
plt.figure(figsize=(8, 5))

ax = sns.barplot(x="Hashtag", y="Pct of Tweets", hue="Sentiment Label", data=summary, ci=None)
for c in ax.containers:
    # custom label calculates percent and add an empty string so 0 value bars don't have a number
    labels = [f'{h/1:0.1f}%' if (h := v.get_height()) > 0 else '' for v in c]
    
    ax.bar_label(c, labels=labels, label_type='edge')

ax.set_yticklabels([])
plt.title('Tweets on the 2022 Ohio Senate Leading Candidates \n', fontsize=16)
plt.show()
